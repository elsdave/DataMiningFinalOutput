# %% [markdown]
# # Final Project in CCS230:Data Mining ⛏️
# # Students' Employability Prediction Based on Mock job Interview Observation Results 🤔🧑‍💼

# %% [markdown]
# The dataset was collected from different university agencies in the Philippines. It consists of Mock job Interview Results of 2.982 observations.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('Student-Employability-Datasets.xlsx')
df
# Out:
#      Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# 0          Student 1                   4                   5
# 1          Student 2                   4                   4
# 2          Student 3                   4                   3
# 3          Student 4                   3                   3
# 4          Student 5                   4                   4
# ...              ...                 ...                 ...
# 2977    Student 2996                   4                   3
# 2978    Student 2997                   3                   4
# 2979    Student 2998                   4                   5
# 2980    Student 2999                   4                   4
# 2981    Student 3000                   4                   4
#
#       PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# 0                      4                 5                5
# 1                      4                 4                4
# ...

# %%
df.shape
# Out:
# (2982, 10)

# %%
df.columns
# Out:
# Index(['Name of Student', 'GENERAL APPEARANCE', 'MANNER OF SPEAKING',
#        'PHYSICAL CONDITION', 'MENTAL ALERTNESS', 'SELF-CONFIDENCE',
#        'ABILITY TO PRESENT IDEAS', 'COMMUNICATION SKILLS',
#        'Student Performance Rating', 'CLASS'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0       Student 1                   4                   5                   4
# 1       Student 2                   4                   4                   4
# 2       Student 3                   4                   3                   3
# 3       Student 4                   3                   3                   3
# 4       Student 5                   4                   4                   3
# 5       Student 6                   4                   4                   3
# 6       Student 7                   4                   4                   4
# 7       Student 8                   5                   3                   3
# 8       Student 9                   4                   4                   4
# 9      Student 10                   4                   4                   3
#
#    MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# ...

# %%
df.describe(include='all')
# Out:
#        Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# count             2982         2982.000000         2982.000000
# unique            2982                 NaN                 NaN
# top       Student 3000                 NaN                 NaN
# freq                 1                 NaN                 NaN
# mean               NaN            4.246814            3.884641
# std                NaN            0.678501            0.757013
# min                NaN            2.000000            2.000000
# 25%                NaN            4.000000            3.000000
# 50%                NaN            4.000000            4.000000
# 75%                NaN            5.000000            4.000000
# max                NaN            5.000000            5.000000
#
#         PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# count          2982.000000       2982.000000      2982.000000
# unique                 NaN               NaN              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2982 entries, 0 to 2981
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name of Student             2982 non-null   object
#  1   GENERAL APPEARANCE          2982 non-null   int64
#  2   MANNER OF SPEAKING          2982 non-null   int64
#  3   PHYSICAL CONDITION          2982 non-null   int64
#  4   MENTAL ALERTNESS            2982 non-null   int64
#  5   SELF-CONFIDENCE             2982 non-null   int64
#  6   ABILITY TO PRESENT IDEAS    2982 non-null   int64
#  7   COMMUNICATION SKILLS        2982 non-null   int64
#  8   Student Performance Rating  2982 non-null   int64
#  9   CLASS                       2982 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 233.1+ KB

# %%
df.isnull().sum()
# Out:
# Name of Student               0
# GENERAL APPEARANCE            0
# MANNER OF SPEAKING            0
# PHYSICAL CONDITION            0
# MENTAL ALERTNESS              0
# SELF-CONFIDENCE               0
# ABILITY TO PRESENT IDEAS      0
# COMMUNICATION SKILLS          0
# Student Performance Rating    0
# CLASS                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Name of Student               2982
# GENERAL APPEARANCE               4
# MANNER OF SPEAKING               4
# PHYSICAL CONDITION               4
# MENTAL ALERTNESS                 4
# SELF-CONFIDENCE                  4
# ABILITY TO PRESENT IDEAS         4
# COMMUNICATION SKILLS             4
# Student Performance Rating       3
# CLASS                            2
# dtype: int64

# %%
df.dtypes
# Out:
# Name of Student               object
# GENERAL APPEARANCE             int64
# MANNER OF SPEAKING             int64
# PHYSICAL CONDITION             int64
# MENTAL ALERTNESS               int64
# SELF-CONFIDENCE                int64
# ABILITY TO PRESENT IDEAS       int64
# COMMUNICATION SKILLS           int64
# Student Performance Rating     int64
# CLASS                         object
# dtype: object

# %% [markdown]
# # Summary of the Dataset 🗒️

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_89633 thead>tr>th {
#   text-align: left;
# }
# #T_89633_row0_col0, #T_89633_row1_col0, #T_89633_row2_col0, #T_89633_row3_col0, #T_89633_row4_col0, #T_89633_row5_col0, #T_89633_row6_col0, #T_89633_row7_col0, #T_89633_row8_col0, #T_89633_row9_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_89633_row0_col1, #T_89633_row1_col1, #T_89633_row2_col1, #T_89633_row3_col1, #T_89633_row4_col1, #T_89633_row5_col1, #T_89633_row6_col1, #T_89633_row7_col1, #T_89633_row8_col1, #T_89633_row9_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_89633_row0_col2, #T_89633_row1_col2, #T_89633_row2_col2, #T_89633_row3_col2, #T_89633_row4_col2, #T_89633_row5_col2, #T_89633_row6_col2, #T_89633_row7_col2, #T_89633_row8_col2, #T_89633_row9_col2 {
# ...

# %% [markdown]
# # Univariate Analysis 🕵🏻‍♂️

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df['GENERAL APPEARANCE'].value_counts()
# Out:
# GENERAL APPEARANCE
# 4    1476
# 5    1129
# 3     361
# 2      16
# Name: count, dtype: int64

# %%
df['GENERAL APPEARANCE'].min()
# Out:
# np.int64(2)

# %%
df['GENERAL APPEARANCE'].mean()
# Out:
# np.float64(4.246814218645205)

# %%
df['GENERAL APPEARANCE'].median()
# Out:
# np.float64(4.0)

# %%
df['GENERAL APPEARANCE'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("GENERAL APPEARANCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of GENERAL APPEARANCE", fontsize=23)

sns.histplot(data=df, x="GENERAL APPEARANCE", kde=True, color='teal')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("GENERAL APPEARANCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of GENERAL APPEARANCE", fontsize=23)

sns.histplot(data=df, x="GENERAL APPEARANCE", kde=True, palette='viridis', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['GENERAL APPEARANCE'], color='teal')

plt.title('Box Plot of GENERAL APPEARANCE', fontsize=20)
plt.xlabel('GENERAL APPEARANCE', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='GENERAL APPEARANCE', data=df, color='teal')

plt.title('GENERAL APPEARANCE', fontsize=20)

plt.xlabel('GENERAL APPEARANCE', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.xlabel("GENERAL APPEARANCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of GENERAL APPEARANCE", fontsize=23)
counts = df['GENERAL APPEARANCE'].value_counts().sort_index() 

colors = sns.light_palette("teal", n_colors=len(counts), reverse=True)

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['MANNER OF SPEAKING'].value_counts()
# Out:
# MANNER OF SPEAKING
# 4    1378
# 3     902
# 5     654
# 2      48
# Name: count, dtype: int64

# %%
df['MANNER OF SPEAKING'].min()
# Out:
# np.int64(2)

# %%
df['MANNER OF SPEAKING'].mean()
# Out:
# np.float64(3.8846411804158283)

# %%
df['MANNER OF SPEAKING'].median()
# Out:
# np.float64(4.0)

# %%
df['MANNER OF SPEAKING'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("MANNER OF SPEAKING", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of MANNER OF SPEAKING", fontsize=23)

sns.histplot(data=df, x="MANNER OF SPEAKING", kde=True, color='indianred')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("MANNER OF SPEAKING", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of MANNER OF SPEAKING", fontsize=23)

sns.histplot(data=df, x="MANNER OF SPEAKING", kde=True, palette='rocket', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['MANNER OF SPEAKING'], color='indianred')

plt.title('Box Plot of MANNER OF SPEAKING', fontsize=20)
plt.xlabel('MANNER OF SPEAKING', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='MANNER OF SPEAKING', data=df, color='indianred')

plt.title('Violin Plot of MANNER OF SPEAKING', fontsize=20)

plt.xlabel('MANNER OF SPEAKING', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.xlabel("GENERAL APPEARANCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of GENERAL APPEARANCE", fontsize=23)
counts = df['GENERAL APPEARANCE'].value_counts().sort_index() 

colors = sns.light_palette("indianred", n_colors=len(counts), reverse=True)

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['PHYSICAL CONDITION'].value_counts()
# Out:
# PHYSICAL CONDITION
# 4    1425
# 3     772
# 5     753
# 2      32
# Name: count, dtype: int64

# %%
df['PHYSICAL CONDITION'].min()
# Out:
# np.int64(2)

# %%
df['PHYSICAL CONDITION'].mean()
# Out:
# np.float64(3.9721663313212607)

# %%
df['PHYSICAL CONDITION'].median()
# Out:
# np.float64(4.0)

# %%
df['PHYSICAL CONDITION'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("PHYSICAL CONDITION", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of PHYSICAL CONDITION", fontsize=23)

sns.histplot(data=df, x="PHYSICAL CONDITION", kde=True, color='turquoise')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("PHYSICAL CONDITION", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of PHYSICAL CONDITION", fontsize=23)

sns.histplot(data=df, x="PHYSICAL CONDITION", kde=True, palette='viridis', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['PHYSICAL CONDITION'], color='turquoise')

plt.title('Box Plot of PHYSICAL CONDITION', fontsize=20)
plt.xlabel('PHYSICAL CONDITION', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='PHYSICAL CONDITION', data=df, color='turquoise')

plt.title('Violin Plot of PHYSICAL CONDITION', fontsize=20)

plt.xlabel('PHYSICAL CONDITION', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("turquoise", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("GENERAL APPEARANCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of GENERAL APPEARANCE", fontsize=23)
counts = df['GENERAL APPEARANCE'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['MENTAL ALERTNESS'].value_counts()
# Out:
# MENTAL ALERTNESS
# 4    1353
# 5     792
# 3     771
# 2      66
# Name: count, dtype: int64

# %%
df['MENTAL ALERTNESS'].min()
# Out:
# np.int64(2)

# %%
df['MENTAL ALERTNESS'].mean()
# Out:
# np.float64(3.9627766599597587)

# %%
df['MENTAL ALERTNESS'].median()
# Out:
# np.float64(4.0)

# %%
df['MENTAL ALERTNESS'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("MENTAL ALERTNESS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of MENTAL ALERTNESS", fontsize=23)

sns.histplot(data=df, x="MENTAL ALERTNESS", kde=True, color='orange')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("MENTAL ALERTNESS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of MENTAL ALERTNESS", fontsize=23)

sns.histplot(data=df, x="MENTAL ALERTNESS", kde=True, palette='YlOrBr', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['MENTAL ALERTNESS'], color='orange')

plt.title('Box Plot of MENTAL ALERTNESS', fontsize=20)
plt.xlabel('MENTAL ALERTNESS', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='MENTAL ALERTNESS', data=df, color='orange')

plt.title('Violin Plot of MENTAL ALERTNESS', fontsize=20)

plt.xlabel('MENTAL ALERTNESS', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("orange", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("MENTAL ALERTNESS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of MENTAL ALERTNESS", fontsize=23)
counts = df['MENTAL ALERTNESS'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['SELF-CONFIDENCE'].value_counts()
# Out:
# SELF-CONFIDENCE
# 4    1113
# 3    1018
# 5     818
# 2      33
# Name: count, dtype: int64

# %%
df['SELF-CONFIDENCE'].min()
# Out:
# np.int64(2)

# %%
df['SELF-CONFIDENCE'].mean()
# Out:
# np.float64(3.9107981220657275)

# %%
df['SELF-CONFIDENCE'].median()
# Out:
# np.float64(4.0)

# %%
df['SELF-CONFIDENCE'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("SELF-CONFIDENCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of SELF-CONFIDENCE", fontsize=23)

sns.histplot(data=df, x="SELF-CONFIDENCE", kde=True, color='lightpink')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("SELF-CONFIDENCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of SELF-CONFIDENCE", fontsize=23)

sns.histplot(data=df, x="SELF-CONFIDENCE", kde=True, palette='cubehelix', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['SELF-CONFIDENCE'], color='lightpink')

plt.title('Box Plot of SELF-CONFIDENCE', fontsize=20)
plt.xlabel('SELF-CONFIDENCE', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='SELF-CONFIDENCE', data=df, color='lightpink')

plt.title('Violin Plot of SELF-CONFIDENCE', fontsize=20)

plt.xlabel('SELF-CONFIDENCE', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("lightpink", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("SELF-CONFIDENCE", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of SELF-CONFIDENCE", fontsize=23)
counts = df['SELF-CONFIDENCE'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['ABILITY TO PRESENT IDEAS'].value_counts()
# Out:
# ABILITY TO PRESENT IDEAS
# 4    1495
# 3     898
# 5     507
# 2      82
# Name: count, dtype: int64

# %%
df['ABILITY TO PRESENT IDEAS'].min()
# Out:
# np.int64(2)

# %%
df['ABILITY TO PRESENT IDEAS'].mean()
# Out:
# np.float64(3.8138832997987926)

# %%
df['ABILITY TO PRESENT IDEAS'].median()
# Out:
# np.float64(4.0)

# %%
df['ABILITY TO PRESENT IDEAS'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("ABILITY TO PRESENT IDEAS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of ABILITY TO PRESENT IDEAS", fontsize=23)

sns.histplot(data=df, x="ABILITY TO PRESENT IDEAS", kde=True, color='purple')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("ABILITY TO PRESENT IDEAS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of ABILITY TO PRESENT IDEAS", fontsize=23)

sns.histplot(data=df, x="ABILITY TO PRESENT IDEAS", kde=True, palette='magma', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['ABILITY TO PRESENT IDEAS'], color='violet')

plt.title('Box Plot of ABILITY TO PRESENT IDEAS', fontsize=20)
plt.xlabel('ABILITY TO PRESENT IDEAS', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='ABILITY TO PRESENT IDEAS', data=df, color='violet')

plt.title('Violin Plot of ABILITY TO PRESENT IDEAS', fontsize=20)

plt.xlabel('ABILITY TO PRESENT IDEAS', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("purple", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("ABILITY TO PRESENT IDEAS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of ABILITY TO PRESENT IDEAS", fontsize=23)
counts = df['ABILITY TO PRESENT IDEAS'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['COMMUNICATION SKILLS'].value_counts()
# Out:
# COMMUNICATION SKILLS
# 3    1376
# 4    1153
# 5     289
# 2     164
# Name: count, dtype: int64

# %%
df['COMMUNICATION SKILLS'].min()
# Out:
# np.int64(2)

# %%
df['COMMUNICATION SKILLS'].mean()
# Out:
# np.float64(3.5254862508383633)

# %%
df['COMMUNICATION SKILLS'].median()
# Out:
# np.float64(3.0)

# %%
df['COMMUNICATION SKILLS'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("COMMUNICATION SKILLS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of COMMUNICATION SKILLS", fontsize=23)

sns.histplot(data=df, x="COMMUNICATION SKILLS", kde=True, color='seagreen')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("COMMUNICATION SKILLS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of COMMUNICATION SKILLS", fontsize=23)

sns.histplot(data=df, x="COMMUNICATION SKILLS", kde=True, palette='crest', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['COMMUNICATION SKILLS'], color='seagreen')

plt.title('Box Plot of COMMUNICATION SKILLS', fontsize=20)
plt.xlabel('COMMUNICATION SKILLS', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='COMMUNICATION SKILLS', data=df, color='seagreen')

plt.title('Violin Plot of COMMUNICATION SKILLS', fontsize=20)

plt.xlabel('COMMUNICATION SKILLS', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("seagreen", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("COMMUNICATION SKILLS", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of COMMUNICATION SKILLS", fontsize=23)
counts = df['COMMUNICATION SKILLS'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %%
df['Student Performance Rating'].value_counts()
# Out:
# Student Performance Rating
# 5    2182
# 4     439
# 3     361
# Name: count, dtype: int64

# %%
df['Student Performance Rating'].min()
# Out:
# np.int64(3)

# %%
df['Student Performance Rating'].mean()
# Out:
# np.float64(4.610663983903421)

# %%
df['Student Performance Rating'].median()
# Out:
# np.float64(5.0)

# %%
df['Student Performance Rating'].max()
# Out:
# np.int64(5)

# %%
plt.figure(figsize=(10,6))

plt.xlabel("Student Performance Rating", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of Student Performance Rating", fontsize=23)

sns.histplot(data=df, x="Student Performance Rating", kde=True, color='lightblue')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.xlabel("Student Performance Rating", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Histplot of Student Performance Rating", fontsize=23)

sns.histplot(data=df, x="Student Performance Rating", kde=True, palette='Blues', hue='CLASS', multiple='stack')

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Student Performance Rating'], color='lightblue')

plt.title('Box Plot of Student Performance Rating', fontsize=20)
plt.xlabel('Student Performance Rating', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='Student Performance Rating', data=df, color='lightblue')

plt.title('Violin Plot of Student Performance Rating', fontsize=20)

plt.xlabel('Student Performance Rating', fontsize=18)

plt.show()

# %%
colors = sns.light_palette("lightblue", n_colors=len(counts), reverse=True)
plt.figure(figsize=(10, 6))

plt.xlabel("Student Performance Rating", fontsize=20)
plt.ylabel("Count", fontsize=20)

plt.title("Pie Chart of Student Performance Rating", fontsize=23)
counts = df['Student Performance Rating'].value_counts().sort_index() 

plt.pie(counts, labels=counts.index, autopct='%.0f%%', startangle=90, colors=colors)
plt.axis('equal') 

plt.show()

# %% [markdown]
# Based on the graphs, it is evident that the questionnaire used by the evaluators utilizes a linear numeric scale of up to 5 points to quantify the attributes of the students.

# %% [markdown]
# Before we continue with our Bivariate Analysis, let's analyze students with a performance rating of 5.

# %%
topper_df = df[df['Student Performance Rating']==5.0]
topper_df
# Out:
#      Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# 0          Student 1                   4                   5
# 1          Student 2                   4                   4
# 2          Student 3                   4                   3
# 3          Student 4                   3                   3
# 4          Student 5                   4                   4
# ...              ...                 ...                 ...
# 2977    Student 2996                   4                   3
# 2978    Student 2997                   3                   4
# 2979    Student 2998                   4                   5
# 2980    Student 2999                   4                   4
# 2981    Student 3000                   4                   4
#
#       PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# 0                      4                 5                5
# 1                      4                 4                4
# ...

# %% [markdown]
# Let's analyze students with a performance rating of 4.

# %%
mid_df = df[df['Student Performance Rating']==4.0]
mid_df
# Out:
#      Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# 13        Student 14                   3                   3
# 15        Student 16                   3                   3
# 16        Student 17                   5                   3
# 24        Student 25                   5                   5
# 56        Student 57                   5                   4
# ...              ...                 ...                 ...
# 2957    Student 2976                   4                   4
# 2962    Student 2981                   4                   4
# 2967    Student 2986                   4                   4
# 2973    Student 2992                   4                   3
# 2976    Student 2995                   5                   3
#
#       PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# 13                     3                 3                3
# 15                     3                 3                3
# ...

# %% [markdown]
# Let's analyze students with performance rating of 3.

# %%
low_df = df[df['Student Performance Rating']==3.0]
low_df
# Out:
#      Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# 6          Student 7                   4                   4
# 21        Student 22                   5                   4
# 23        Student 24                   4                   3
# 25        Student 26                   5                   5
# 26        Student 27                   4                   4
# ...              ...                 ...                 ...
# 2932    Student 2951                   4                   4
# 2935    Student 2954                   5                   4
# 2940    Student 2959                   5                   3
# 2942    Student 2961                   5                   5
# 2947    Student 2966                   5                   4
#
#       PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# 6                      4                 3                3
# 21                     4                 4                4
# ...

# %% [markdown]
# We can observe that having a high performance rating does not directly imply being employable. We would need to get the average of all features in order to further examine why did the observers classify the students as employable or less employable.

# %% [markdown]
# # Data Encoding for Class Feature 🕵🏻‍♂️

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['Class_Encoded'] = LabelEncoder().fit_transform(df['CLASS'])
df['Class_Encoded']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 2977    0
# 2978    0
# 2979    0
# 2980    1
# 2981    0
# Name: Class_Encoded, Length: 2982, dtype: int64

# %%
df['CLASS']
# Out:
# 0           Employable
# 1           Employable
# 2       LessEmployable
# 3       LessEmployable
# 4           Employable
#              ...
# 2977        Employable
# 2978        Employable
# 2979        Employable
# 2980    LessEmployable
# 2981        Employable
# Name: CLASS, Length: 2982, dtype: object

# %% [markdown]
# * 1 corresponds to LessEmployable
# * 0 corresponds to Employable

# %% [markdown]
# # Bivariate Analysis 🚀✨

# %%
features = [
    'GENERAL APPEARANCE', 'MANNER OF SPEAKING', 'PHYSICAL CONDITION',
    'MENTAL ALERTNESS', 'SELF-CONFIDENCE', 'ABILITY TO PRESENT IDEAS',
    'COMMUNICATION SKILLS', 'Student Performance Rating'
]

df['EMPLOYABILITY_SCORE'] = df[features].mean(axis=1)
df['EMPLOYABILITY_SCORE']
# Out:
# 0       4.750
# 1       4.000
# 2       3.250
# 3       3.125
# 4       3.750
#         ...
# 2977    3.250
# 2978    4.000
# 2979    4.375
# 2980    3.875
# 2981    4.000
# Name: EMPLOYABILITY_SCORE, Length: 2982, dtype: float64

# %%
print(df.head())
# Out:
#   Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0       Student 1                   4                   5                   4
# 1       Student 2                   4                   4                   4
# 2       Student 3                   4                   3                   3
# 3       Student 4                   3                   3                   3
# 4       Student 5                   4                   4                   3
#
#    MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                 5                5                         5
# 1                 4                4                         4
# 2                 3                3                         3
# 3                 2                3                         3
# 4                 3                4                         4
#
#    COMMUNICATION SKILLS  Student Performance Rating           CLASS  \
# ...

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
X = df.drop(columns = ['Name of Student', 'CLASS', 'Class_Encoded'])
y = df['CLASS']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.1, random_state=42)

# %%
catboost_model = CatBoostClassifier(iterations=500, learning_rate=0.01, depth=6, verbose=False, random_state=42, bagging_temperature=2, l2_leaf_reg=7 )
catboost_model.fit(X_train, y_train)

# %%
y_pred = catboost_model.predict(X_test)
y_pred
# Out:
# array(['Employable', 'LessEmployable', 'Employable', 'LessEmployable',
#        'LessEmployable', 'LessEmployable', 'Employable', 'Employable',
#        'Employable', 'LessEmployable', 'Employable', 'Employable',
#        'LessEmployable', 'Employable', 'Employable', 'LessEmployable',
#        'LessEmployable', 'Employable', 'LessEmployable', 'LessEmployable',
#        'Employable', 'Employable', 'LessEmployable', 'Employable',
#        'Employable', 'Employable', 'Employable', 'Employable',
#        'Employable', 'Employable', 'LessEmployable', 'Employable',
#        'LessEmployable', 'LessEmployable', 'LessEmployable', 'Employable',
#        'Employable', 'Employable', 'Employable', 'LessEmployable',
#        'Employable', 'Employable', 'Employable', 'Employable',
#        'Employable', 'Employable', 'Employable', 'LessEmployable',
#        'LessEmployable', 'LessEmployable', 'Employable', 'LessEmployable',
#        'Employable', 'Employable', 'Employable', 'LessEmployable',
# ...

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9297658862876255

# %%
print(f'Accuracy: {accuracy:.4f}')
print(f'Percentage Accuracy: {accuracy*100}%')
# Out:
# Accuracy: 0.9298
# Percentage Accuracy: 92.97658862876254%

# %%
classification_report_catboost = classification_report(y_test, y_pred)
print(classification_report_catboost)
# Out:
#                 precision    recall  f1-score   support
#
#     Employable       0.92      0.96      0.94       167
# LessEmployable       0.94      0.89      0.92       132
#
#       accuracy                           0.93       299
#      macro avg       0.93      0.93      0.93       299
#   weighted avg       0.93      0.93      0.93       299
